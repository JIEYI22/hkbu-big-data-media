# %%
import pandas as pd
import matplotlib 
import plotly
import seaborn as sns
from pandas import Series,DataFrame
import csv

# %%
import lxml
import parser

# %%
df=pd.read_csv('Shenzhen_51job_test.csv', encoding= 'gb18030')

# %%
df
# Out:
#                   Total_position        Total_company  Salary_per_month
# 0                             礼仪        深圳市初心传媒发展有限公司       6000.000000
# 1                           销售专员                东方福利网       8333.333333
# 2                           招生专员      深圳市华影东方文化发展有限公司       3500.000000
# 3               10086纯接听客服文员（包住）      大不同信息产业（深圳）有限公司       4500.000000
# 4                            配音师     巨人媒体网络文化（深圳）有限公司       3000.000000
# 5                   实习岗位-幼少儿英语助教     深圳市童心爱文化传播有限责任公司       8000.000000
# 6                           推广专员        深圳市云卓数码科技有限公司       6000.000000
# 7                           销售助理        深圳市中科创威科技有限公司       3000.000000
# 8                         前台课程顾问      深圳市东亮教育信息咨询有限公司       4500.000000
# 9                           统计文员         深圳市铭仕创印刷有限公司       3000.000000
# 10                  无责任底薪6000+提成       豪天文化传媒（深圳）有限公司       6000.000000
# 11                          市场专员        深圳市世纪东方会展有限公司       3000.000000
# 12                           业务员       深圳前海逸途信息科技有限公司       4500.000000
# 13                          行政专员        深圳市精准分众传媒有限公司       4000.000000
# 14                           模型师        深圳市朗形数字科技有限公司       8000.000000
# 15                            会计         深圳腾清动漫股份有限公司       4000.000000
# 16                        市场公关助理         锋镝传媒（深圳）有限公司       5000.000000
# 17                     办公室文员/应届生        深圳市蓝景创意设计有限公司       3000.000000
# 18                    助理设计师（应届生）           深圳途胜广告有限公司       4500.000000
# 19                      毕业生平面设计师         深圳善觉品牌建设有限公司       4000.000000
# 20                  可新人舞蹈队员包吃住8k      深圳市聚力联城文化传媒有限公司      10000.000000
# 21                          早教老师       深圳海雅瑞德信息咨询有限公司       4000.000000
# 22                         办公室文员          深圳自由人传媒有限公司       3000.000000
# 23                          销售代表        深圳市森火展览展示有限公司       8000.000000
# 24                        活动策划专员        深圳市卓祺文化传播有限公司       3000.000000
# 25               设计\电商储备岗位  总监助理         深圳电酷电子商务有限公司       4500.000000
# 26           电话销售/销售专员/销售代表/客户代表  深圳宜和股份有限公司（深视宜和购...       4000.000000
# 27                       陈列设计师助理      深圳市诺维品牌形象设计有限公司       3000.000000
# 28                        平面设计助理        深圳市轩辕艺术设计有限公司       3000.000000
# 29                          视频主播         深圳纵横蜂巢传媒有限公司      10000.000000
# ...                          ...                  ...               ...
# 2399                新媒体推广 网络整合营销         深圳拍宝网络科技有限公司      20000.000000
# 2400                  娱乐/音乐/跳舞主播       深圳市天之羽文化发展有限公司       8000.000000
# 2401                   实习生（广告策划）       深圳市天之羽文化发展有限公司       5000.000000
# 2402                     见习平面设计师       深圳市天之羽文化发展有限公司       5000.000000
# 2403                   实习摄影师、剪辑师       深圳市天之羽文化发展有限公司       8000.000000
# 2404                 灯光师学徒、音响师学徒        深圳市雅兰印刷包装有限公司       4500.000000
# 2405             工业设计师助理，工业设计实习生        深圳市雅兰印刷包装有限公司       4500.000000
# 2406                     市场研究实习生        深圳市雅兰印刷包装有限公司       4500.000000
# 2407                       大客户销售        深圳市雅兰印刷包装有限公司       4500.000000
# 2408                       公关实习生        深圳市雅兰印刷包装有限公司       4500.000000
# 2409                     文案策划实习生        深圳市雅兰印刷包装有限公司       6000.000000
# 2410        置业顾问房产经纪人房地产销售销售代表链家       深圳市天之羽文化发展有限公司       8000.000000
# 2411                     应届-后期制作        深圳市华夏动漫科技有限公司       4000.000000
# 2412                外国模特经纪booker        深圳市博宇文化发展有限公司       8000.000000
# 2413                    项目区域代理高薪       深圳中广艺影文化传媒有限公司       4500.000000
# 2414                珠宝销售网络主播（靠谱）         深圳市正音堂乐器有限公司       5000.000000
# 2415       插画师 平面设计师  图案设计师 陶瓷花面          深圳市通和广告有限公司       3000.000000
# 2416                  深圳招总经理秘书助理     深圳中影博纳影视文化传媒有限公司       3000.000000
# 2417      插画师 平面设计师  图案设计师 陶瓷花面设        北京龙族星工厂娱乐有限公司      50000.000000
# 2418                  深圳招总经理秘书助理      深圳市巴黎春天婚纱摄影有限公司       1666.666667
# 2419                    深圳招总经理助理    深圳市心智定位品牌互动营销有限公司       2000.000000
# 2420  多职位插画师 平面设计师  图案设计师 陶瓷花面设计        深圳市炫彩视听设备有限公司       2500.000000
# 2421  多职位插画师 平面设计师  图案设计师 陶瓷花面设计        深圳市思睿博雅咨询有限公司       2800.000000
# 2422      插画师 平面设计师  图案设计师 陶瓷花面设      新好耶数字技术（上海）有限公司       1500.000000
# 2423                  深圳招总经理秘书助理    深圳市香港卫视国际传媒艺术有限公司          0.000000
# 2424                  深圳招总经理秘书助理          深圳海棠果影业有限公司       2000.000000
# 2425                  深圳招总经理秘书助理        深圳市博悦创想科技有限公司       5000.000000
# 2426  多职位插画师 平面设计师  图案设计师 陶瓷花面设计       深圳市星悦乐文化传媒有限公司       5000.000000
# 2427  多职位插画师 平面设计师  图案设计师 陶瓷花面设计       深圳市星悦乐文化传媒有限公司       5000.000000
# 2428  多职位插画师 平面设计师  图案设计师 陶瓷花面设计       深圳市星悦乐文化传媒有限公司       5000.000000
#
# [2429 rows x 3 columns]

# %% [markdown]
# 以传播学专业就业主要几个方向作为关键词进行筛选
# 内容生产方向：记者／文案／编辑／广告／文化传播
# 营销策划方向：公关／策划／推广／市场研究／销售／营销
# 其他：行政／文员

# %%
df_content_generator=df['Total_position'].apply(lambda t:'记者' in str(t))|df['Total_position'].apply(lambda t:'文案' in str(t))|df['Total_position'].apply(lambda t:'编辑' in str(t))|df['Total_position'].apply(lambda t:'广告' in str(t))|df['Total_position'].apply(lambda t:'文化传播' in str(t))

# %%
df[df_content_generator]
# Out:
#                    Total_position      Total_company  Salary_per_month
# 56                       自媒体/文案编辑      鑫商圈集团（深圳）有限公司       8000.000000
# 91                     微信公众号运营/编辑      深圳市金展文化传媒有限公司       4000.000000
# 147                          文案编辑     深圳丝路数字视觉股份有限公司       4500.000000
# 148                 初级广告设计师/应届生亦可     深圳市歆威迪文化发展有限公司       8000.000000
# 157   融异广告雏鹰计划-文案策划/编辑/广告创意实习生/助理       深圳市中科睿科技有限公司       3000.000000
# 175                       互联网广告销售      深圳市福田区平行咨询工作室       4166.666667
# 199                   网络编辑 编辑经验不限       上海聚胜万合广告有限公司       2200.000000
# 202                     助理文案（实习生）     深圳市西游网网络科技有限公司       3000.000000
# 213                      广告喷绘后期制作        深圳市汉马展览有限公司       3500.000000
# 220                       品牌文案/策划      佳兆业文化体育发展有限公司       4500.000000
# 226                            文案       深圳市米高梅影业有限公司       8000.000000
# 265                          内容编辑     深圳市子之源教育科技有限公司       5000.000000
# 267                       微信公众号编辑      深圳市盈合数字技术有限公司       6000.000000
# 282                       腾讯广告合伙人  深圳市筑梦公社应用美术设计有限公司       4000.000000
# 297                            编辑     深圳市七彩芯光电科技有限公司       5000.000000
# 312                 广告项目专员（实习生皆可）       深圳市奥尔美广告有限公司          0.000000
# 314               广告销售代表（双休+五险一金）        深圳市新意设计有限公司       3000.000000
# 321                 新媒体运营/编辑（实习生）     深圳云盟互动网络技术有限公司       8000.000000
# 333         茶馆前台文员(3800-5000）文案营销   上海窗之外广告有限公司深圳分公司       6000.000000
# 342                            文案   深圳市青蓝紫文化艺术发展有限公司       3000.000000
# 351                         记者、编辑     深圳市乐启发文化传播有限公司       3000.000000
# 363              公众号编辑/新媒体编辑（实习生）      深圳市品索教育科技有限公司       4500.000000
# 365                          广告设计       深圳热播网络科技有限公司       4000.000000
# 371                          文案策划           金柏电子有限公司       4000.000000
# 385                          文案策划        深圳市沛才科技有限公司      10000.000000
# 389                          文案助理       深圳前海易联科技有限公司       3000.000000
# 407                 内容运营编辑（欢迎应届生）                公司名          0.000000
# 408                         编辑/文案    深圳市太华世纪文化传播有限公司       5000.000000
# 415                          编辑助理     我看网络技术（北京）有限公司       4000.000000
# 417                          文案助理    深圳市魔力体育文化发展有限公司       4000.000000
# ...                           ...                ...               ...
# 1836                       广告项目专员      深圳市点石数码科技有限公司       4500.000000
# 1841                       急聘网站编辑        深圳市佳胜实业有限公司       4000.000000
# 1842                         网站编辑      深圳世纪云文化传媒有限公司       4500.000000
# 1846                      微信公众号编辑     深圳市乐有家房产交易有限公司       8000.000000
# 1850                      见习/助理文案   华强方特文化科技集团股份有限公司       6000.000000
# 1870                       广告客户经理     极致文化传媒（深圳）有限公司      10000.000000
# 1921                   文案/策划/文案策划     深圳市上书房信息咨询有限公司       2000.000000
# 1922                     文案/策划/双休        深圳市人工智能行业协会       8000.000000
# 1934                       广告销售专员   深圳市模范好少年文化发展有限公司       6000.000000
# 1955                广告销售（应届毕业生皆可）      深圳链家房地产经纪有限公司       5000.000000
# 1960               广告销售专员 底薪5k+提成   深圳智仕团队品牌互动营销有限公司       4000.000000
# 1986                         策划文案        深圳市时尚传媒有限公司       6000.000000
# 2033                广告客服助理/广告AE助理    深圳市形尚品牌文化传播有限公司       3000.000000
# 2052                         文案策划   深圳市童心爱文化传播有限责任公司       6000.000000
# 2057                         文案助理      深圳市盛航伊甸科技有限公司       4000.000000
# 2065                     广告标识学徒小工        深圳市时尚传媒有限公司       6000.000000
# 2101                     广告标识公司学徒              东方福利网       8333.333333
# 2140       编辑策划/组稿文员/组稿专员/文字编辑/文秘      深圳链家房地产经纪有限公司       5000.000000
# 2145          广告策划/策划专员/策划文案/广告运营      深圳市乐道形象策划有限公司       5000.000000
# 2151       内容/媒体运营/内容编辑/运营顾问/运营推广     深圳市上书房信息咨询有限公司       4500.000000
# 2189          广告销售/客户代表/广告拓展/广告文案       上海百倍丰朴科技有限公司       6500.000000
# 2190            广告/广告拓展/广告文案/广告销售       上海百倍丰朴科技有限公司       6500.000000
# 2219                       创意文案策划       上海百倍丰朴科技有限公司      11000.000000
# 2242                         文案策划       上海百倍丰朴科技有限公司      10000.000000
# 2278                        文案实习生       上海百倍丰朴科技有限公司       4000.000000
# 2330                           文案     深圳市上书房信息咨询有限公司       3000.000000
# 2382                     文案策划 实习生      深圳市投缘文化传播有限公司      10000.000000
# 2384                      文案策划实习生      成都匠客儿文化传媒有限公司       6000.000000
# 2401                    实习生（广告策划）     深圳市天之羽文化发展有限公司       5000.000000
# 2409                      文案策划实习生      深圳市雅兰印刷包装有限公司       6000.000000
#
# [139 rows x 3 columns]

# %%
df[df_content_generator].describe()
# Out:
#        Salary_per_month
# count        139.000000
# mean        5388.489209
# std         2262.096530
# min            0.000000
# 25%         4000.000000
# 50%         5000.000000
# 75%         6500.000000
# max        11000.000000

# %%
contend_salary_mean=df[df_content_generator].mean()

# %%
contend_salary_mean
# Out:
# Salary_per_month    5388.489209
# dtype: float64

# %%
content_position=df_content_generator.aggregate('sum')
content_position
# Out:
# 139

# %%
df_marketing=df['Total_position'].apply(lambda t:'公关' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'销售' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'营销' in str(t))

# %%
df[df_marketing]
# Out:
#                      Total_position        Total_company  Salary_per_month
# 1                              销售专员                东方福利网       8333.333333
# 6                              推广专员        深圳市云卓数码科技有限公司       6000.000000
# 7                              销售助理        深圳市中科创威科技有限公司       3000.000000
# 16                           市场公关助理         锋镝传媒（深圳）有限公司       5000.000000
# 23                             销售代表        深圳市森火展览展示有限公司       8000.000000
# 24                           活动策划专员        深圳市卓祺文化传播有限公司       3000.000000
# 26              电话销售/销售专员/销售代表/客户代表  深圳宜和股份有限公司（深视宜和购...       4000.000000
# 30                           外贸销售业务        深圳市卓扬光电科技有限公司       5000.000000
# 43               急聘网络销售+包住+无责底薪3500         深圳鸿盛网络传媒有限公司       3000.000000
# 44               销售代表/业务代表/业务员/销售专员      深圳市鸿图设计影视传媒有限公司       8000.000000
# 45                        营销储备生（深圳）           奥飞娱乐股份有限公司       3800.000000
# 46                           网络客服销售      深圳市巴黎春天婚纱摄影有限公司       6000.000000
# 48              急聘网络销售+有无经验均可+无责任底薪        深圳春鼎聚信息技术有限公司       4000.000000
# 50                             销售代表                  公司名          0.000000
# 53                             电话销售         深圳市特美工艺品有限公司       4500.000000
# 54                             软件销售        深圳市米泰包装设计有限公司       4500.000000
# 58                          互联网销售代表         广州反斗文化传播有限公司       4500.000000
# 66                      高薪诚聘艺术品销售代表        深圳市炫彩视听设备有限公司       3000.000000
# 69                         外展销售/业务员        深圳市和乐文化传播有限公司       3000.000000
# 81                       销售代表+双休+底薪               励展博览集团       2000.000000
# 85                        高薪急聘 网络销售    深圳市心智定位品牌互动营销有限公司       3000.000000
# 86                  销售/销售代表（京东无界零售）       深圳市诺百世电子科技有限公司       4500.000000
# 89           网络销售/底薪4300起/只招新手无经验优先             深圳书城培训中心       4000.000000
# 92                             销售代表        深圳市朝歌文化传播有限公司       5000.000000
# 95                       销售培训生（毕业生）       华臻（深圳）展览服务有限公司       8000.000000
# 96                             销售代表        深圳市黑马数字科技有限公司       4500.000000
# 97                         教育培训销售顾问       深圳北斗星光文化传媒有限公司       5000.000000
# 100                          区域销售经理        深圳市立阳书画教育有限公司       3000.000000
# 102                            销售代表          深圳迪帕森乐器有限公司       6000.000000
# 105                 （周末双休高提成）粤语电话销售        深圳市柏林影视科技有限公司       4500.000000
# ...                             ...                  ...               ...
# 2312                 链家冠军团队召集地产销售战友        深圳市咸鱼文化传媒有限公司       5000.000000
# 2321                           销售代表        深圳链家房地产经纪有限公司       5000.000000
# 2322                         高端房产销售        深圳市朗图品牌设计有限公司       2500.000000
# 2323                           业务销售        深圳市朗图品牌设计有限公司       3000.000000
# 2324                           销售代表        深圳市朗图品牌设计有限公司       2500.000000
# 2325                           销售代表         深圳市意景廊设计有限公司       2000.000000
# 2326                     金领待遇聘：销售经理        深圳链家房地产经纪有限公司       5000.000000
# 2328                    两万月薪诚聘：销售经理       深圳市上书房信息咨询有限公司       4000.000000
# 2332                           销售代表       深圳市上书房信息咨询有限公司       4000.000000
# 2346                         教育行业销售           ACTO 梦空间影城       3000.000000
# 2351  播音主持人/司仪/讲师/珠宝销售/淘宝网络主播/网红KOL        深圳链家房地产经纪有限公司      10000.000000
# 2352                       珠宝销售网络主播        深圳链家房地产经纪有限公司       5000.000000
# 2357                 电话客服/电话销售 （包住）        深圳链家房地产经纪有限公司       5000.000000
# 2359                  电话销售顾问（包住+餐补）        深圳链家房地产经纪有限公司       5000.000000
# 2361                 销售代表 / 业务 （包住）        深圳链家房地产经纪有限公司       5000.000000
# 2362              包装设计销售经理/销售主管（包住）        深圳链家房地产经纪有限公司       5000.000000
# 2378                        大客户销售代表        深圳市成风世纪广告有限公司       5000.000000
# 2382                       文案策划 实习生        深圳市投缘文化传播有限公司      10000.000000
# 2384                        文案策划实习生        成都匠客儿文化传媒有限公司       6000.000000
# 2388                           销售代表         深圳市星亚辉广告有限公司       3000.000000
# 2394                           销售代表        深圳市华夏动漫科技有限公司       4500.000000
# 2396                          大客户销售                  公司名          0.000000
# 2399                   新媒体推广 网络整合营销         深圳拍宝网络科技有限公司      20000.000000
# 2401                      实习生（广告策划）       深圳市天之羽文化发展有限公司       5000.000000
# 2406                        市场研究实习生        深圳市雅兰印刷包装有限公司       4500.000000
# 2407                          大客户销售        深圳市雅兰印刷包装有限公司       4500.000000
# 2408                          公关实习生        深圳市雅兰印刷包装有限公司       4500.000000
# 2409                        文案策划实习生        深圳市雅兰印刷包装有限公司       6000.000000
# 2410           置业顾问房产经纪人房地产销售销售代表链家       深圳市天之羽文化发展有限公司       8000.000000
# 2414                   珠宝销售网络主播（靠谱）         深圳市正音堂乐器有限公司       5000.000000
#
# [633 rows x 3 columns]

# %%
df[df_marketing].describe()
# Out:
#        Salary_per_month
# count        633.000000
# mean        5305.845182
# std         2506.722865
# min            0.000000
# 25%         4000.000000
# 50%         5000.000000
# 75%         6000.000000
# max        20000.000000

# %%
marketing_position=df_marketing.aggregate('sum')
marketing_position
# Out:
# 633

# %%
marketing_salary_mean=df[df_marketing].mean()
marketing_salary_mean
# Out:
# Salary_per_month    5305.845182
# dtype: float64

# %%
df_other=df['Total_position'].apply(lambda t:'行政' in str(t))|df['Total_position'].apply(lambda t:'文员' in str(t))

# %%
df[df_other]
# Out:
#               Total_position      Total_company  Salary_per_month
# 3           10086纯接听客服文员（包住）    大不同信息产业（深圳）有限公司       4500.000000
# 9                       统计文员       深圳市铭仕创印刷有限公司       3000.000000
# 13                      行政专员      深圳市精准分众传媒有限公司       4000.000000
# 17                 办公室文员/应届生      深圳市蓝景创意设计有限公司       3000.000000
# 22                     办公室文员        深圳自由人传媒有限公司       3000.000000
# 31                 前台文员/行政助理     财富文化产业（深圳）有限公司       4500.000000
# 60                 物流跟单/物流文员      深圳链家房地产经纪有限公司       5000.000000
# 71                      行政前台      深圳市万合文化传播有限公司       6000.000000
# 77                      行政助理      深圳大灵猫传媒文化有限公司      10000.000000
# 80                   前台行政实习生         深圳今一文化有限公司       4500.000000
# 98                 前台文员/人事助理       深圳韵诚文化传播有限公司       6000.000000
# 104                     行政文员     深圳喜沃互动网络科技有限公司       6000.000000
# 113                     行政文员  深圳市卓筑文旅设计科技发展有限公司       3000.000000
# 120                       文员      深圳市亿科思奇广告有限公司       4000.000000
# 155                     前台文员     深圳纵横南方影院发展有限公司       3000.000000
# 161                     行政前台      深圳市约克文化传播有限公司       8000.000000
# 174                     行政助理     深圳合众奇迹文化传媒有限公司       5000.000000
# 176            审核文员不限经验5600起         ACTO 梦空间影城       4000.000000
# 182                     出纳行政        深圳市卓京影业有限公司       3500.000000
# 186               行政助理（财务方向)      深圳市瀚宇会议策划有限公司       4500.000000
# 218                行政助理/媒介助理      北京龙族星工厂娱乐有限公司       6666.666667
# 227                     行政助理       深圳前瞻资讯股份有限公司       6000.000000
# 229                     会计文员    深圳市夜映网络研发科技有限公司       5000.000000
# 234                     售后文员     深圳市奥思艺文化传播有限公司       3000.000000
# 246                     前台行政       深圳微盐传媒科技有限公司       4000.000000
# 251                     前台文员      深圳市半糖设计顾问有限公司       3000.000000
# 276                     行政客服    朱古力设计咨询（深圳）有限公司       2500.000000
# 280                   前台行政文员    红绿蓝展示制品（深圳）有限公司       6000.000000
# 289                     前台文员   深圳市龙华新区芳妮豆丁影像儿童馆       2000.000000
# 296                     行政前台       深圳市华巨臣实业有限公司       4500.000000
# ...                      ...                ...               ...
# 2152   运营助理/行政专员/市场助理/市场营销专员     深圳市上书房信息咨询有限公司       6000.000000
# 2168     财务助理/财务分析/财务文员/会计助理       上海百倍丰朴科技有限公司       8000.000000
# 2170     秘书/文员/办公室文员/助理/人事文员       上海百倍丰朴科技有限公司      10000.000000
# 2171  行政助理/后勤专员/行政前台/行政秘书/文员       上海百倍丰朴科技有限公司       8000.000000
# 2172    部门助理/秘书/文员/客服文员/行政人事       上海百倍丰朴科技有限公司       8000.000000
# 2173    行政专员/助理/行政秘书/行政前台/文员       上海百倍丰朴科技有限公司      10000.000000
# 2174      办公室主任/行政主管/行政/人事经理       上海百倍丰朴科技有限公司       8000.000000
# 2177    人事/行政/人力资源/人事助理/人事实习       上海百倍丰朴科技有限公司      15000.000000
# 2178     人事行政/人事前台/人事助理/人事主管       上海百倍丰朴科技有限公司       4500.000000
# 2184   销售运营支持/销售顾问/运营推广/销售行政       上海百倍丰朴科技有限公司       6500.000000
# 2185   商务行政助理/商务运营/商务文员/商务代表       上海百倍丰朴科技有限公司       5000.000000
# 2186     销售顾问/销售专员/行政文员/销售行政       上海百倍丰朴科技有限公司       6500.000000
# 2206   总经理司机/机动车司机/专职司机/行政司机       上海百倍丰朴科技有限公司       4500.000000
# 2217                  信息录入文员       上海百倍丰朴科技有限公司      11000.000000
# 2234              行政专员/助理/文员       上海百倍丰朴科技有限公司      11000.000000
# 2244                    行政助理       上海百倍丰朴科技有限公司       4500.000000
# 2247                    行政文员       上海百倍丰朴科技有限公司       8000.000000
# 2264                    前台文员       上海百倍丰朴科技有限公司       4000.000000
# 2265                    前台行政       上海百倍丰朴科技有限公司       6000.000000
# 2269                  人事行政专员       上海百倍丰朴科技有限公司       8000.000000
# 2280                   办公室文员       上海百倍丰朴科技有限公司       5000.000000
# 2302                    行政前台              东方福利网       8333.333333
# 2339                    前台行政    深圳市荣凯艺瑞文化传播有限公司       3000.000000
# 2344                  沙井文员双休         ACTO 梦空间影城       3000.000000
# 2347                  诚聘文员双休         ACTO 梦空间影城       3000.000000
# 2349                    行政专员      深圳链家房地产经纪有限公司       5000.000000
# 2360            前台文员 （包住+餐补）      深圳链家房地产经纪有限公司       5000.000000
# 2366                 行政助理兼前台      深圳链家房地产经纪有限公司       5000.000000
# 2374        行政助理兼前台（龙岗中心城急招）  深圳中鉴艺术品鉴定评估管理有限公司       8000.000000
# 2385                 行政专员/助理   正一会馆（深圳）文化管理有限公司       4500.000000
#
# [209 rows x 3 columns]

# %%
df[df_other].describe()
# Out:
#        Salary_per_month
# count        209.000000
# mean        5647.527911
# std         3723.073629
# min            0.000000
# 25%         4000.000000
# 50%         4500.000000
# 75%         6500.000000
# max        40000.000000

# %%
other_salary_mean=df[df_other].mean()
other_salary_mean
# Out:
# Salary_per_month    5647.527911
# dtype: float64

# %%
other_position=df_other.aggregate('sum')
other_position
# Out:
# 209

# %%
import matplotlib 
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
from plotly.graph_objs import Scatter, Layout
import numpy as np
from plotly.graph_objs import Bar
from plotly.offline import iplot
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df=pd.read_csv('Shanghai_51job.csv', encoding= 'gb18030')
df_content_generator=df['Total_position'].apply(lambda t:'记者' in str(t))|df['Total_position'].apply(lambda t:'文案' in str(t))|df['Total_position'].apply(lambda t:'编辑' in str(t))|df['Total_position'].apply(lambda t:'广告' in str(t))|df['Total_position'].apply(lambda t:'文化传播' in str(t))
shanghai_content_position=df_content_generator.aggregate('sum')
shanghai_contend_salary_mean=df[df_content_generator].mean()
df_marketing=df['Total_position'].apply(lambda t:'公关' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'销售' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'营销' in str(t))
shanghai_marketing_position=df_marketing.aggregate('sum')
shanghai_marketing_salary_mean=df[df_marketing].mean()
df_other=df['Total_position'].apply(lambda t:'行政' in str(t))|df['Total_position'].apply(lambda t:'文员' in str(t))
shanghai_other_position=df_other.aggregate('sum')
shanghai_other_salary_mean=df[df_other].mean()

# %%
df=pd.read_csv('Guangzhou_51job.csv', encoding= 'gb18030')
df_content_generator=df['Total_position'].apply(lambda t:'记者' in str(t))|df['Total_position'].apply(lambda t:'文案' in str(t))|df['Total_position'].apply(lambda t:'编辑' in str(t))|df['Total_position'].apply(lambda t:'广告' in str(t))|df['Total_position'].apply(lambda t:'文化传播' in str(t))
guangzhou_content_position=df_content_generator.aggregate('sum')
guangzhou_contend_salary_mean=df[df_content_generator].mean()
df_marketing=df['Total_position'].apply(lambda t:'公关' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'销售' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'营销' in str(t))
guangzhou_marketing_position=df_marketing.aggregate('sum')
guangzhou_marketing_salary_mean=df[df_marketing].mean()
df_other=df['Total_position'].apply(lambda t:'行政' in str(t))|df['Total_position'].apply(lambda t:'文员' in str(t))
guangzhou_other_position=df_other.aggregate('sum')
guangzhou_other_salary_mean=df[df_other].mean()

# %%
df=pd.read_csv('Hangzhou_51job.csv', encoding= 'gb18030')
df_content_generator=df['Total_position'].apply(lambda t:'记者' in str(t))|df['Total_position'].apply(lambda t:'文案' in str(t))|df['Total_position'].apply(lambda t:'编辑' in str(t))|df['Total_position'].apply(lambda t:'广告' in str(t))|df['Total_position'].apply(lambda t:'文化传播' in str(t))
Hangzhou_content_position=df_content_generator.aggregate('sum')
Hangzhou_contend_salary_mean=df[df_content_generator].mean()
df_marketing=df['Total_position'].apply(lambda t:'公关' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'销售' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'营销' in str(t))
Hangzhou_marketing_position=df_marketing.aggregate('sum')
Hangzhou_marketing_salary_mean=df[df_marketing].mean()
df_other=df['Total_position'].apply(lambda t:'行政' in str(t))|df['Total_position'].apply(lambda t:'文员' in str(t))
Hangzhou_other_position=df_other.aggregate('sum')
Hangzhou_other_salary_mean=df[df_other].mean()

# %%
df=pd.read_csv('Chengdu_51job.csv', encoding= 'gb18030')
df_content_generator=df['Total_position'].apply(lambda t:'记者' in str(t))|df['Total_position'].apply(lambda t:'文案' in str(t))|df['Total_position'].apply(lambda t:'编辑' in str(t))|df['Total_position'].apply(lambda t:'广告' in str(t))|df['Total_position'].apply(lambda t:'文化传播' in str(t))
chengdu_content_position=df_content_generator.aggregate('sum')
Chengdu_contend_salary_mean=df[df_content_generator].mean()
df_marketing=df['Total_position'].apply(lambda t:'公关' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'销售' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'营销' in str(t))
Chengdu_marketing_position=df_marketing.aggregate('sum')
Chengdu_marketing_salary_mean=df[df_marketing].mean()
df_other=df['Total_position'].apply(lambda t:'行政' in str(t))|df['Total_position'].apply(lambda t:'文员' in str(t))
Chengdu_other_position=df_other.aggregate('sum')
Chengdu_other_salary_mean=df[df_other].mean()

# %%
df=pd.read_csv('Beijing_51job.csv', encoding= 'gb18030')
df_content_generator=df['Total_position'].apply(lambda t:'记者' in str(t))|df['Total_position'].apply(lambda t:'文案' in str(t))|df['Total_position'].apply(lambda t:'编辑' in str(t))|df['Total_position'].apply(lambda t:'广告' in str(t))|df['Total_position'].apply(lambda t:'文化传播' in str(t))
Beijing_content_position=df_content_generator.aggregate('sum')
Beijing_contend_salary_mean=df[df_content_generator].mean()
df_marketing=df['Total_position'].apply(lambda t:'公关' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'销售' in str(t))|df['Total_position'].apply(lambda t:'策划' in str(t))|df['Total_position'].apply(lambda t:'推广' in str(t))|df['Total_position'].apply(lambda t:'市场研究' in str(t))|df['Total_position'].apply(lambda t:'营销' in str(t))
Beijing_marketing_position=df_marketing.aggregate('sum')
Beijing_marketing_salary_mean=df[df_marketing].mean()
df_other=df['Total_position'].apply(lambda t:'行政' in str(t))|df['Total_position'].apply(lambda t:'文员' in str(t))
Beijing_other_position=df_other.aggregate('sum')
Beijing_other_salary_mean=df[df_other].mean()

# %%
trace1 = {
  "x": ["content generation", "marketing", "other related"], 
  "y": [float(Beijing_contend_salary_mean),float(Beijing_marketing_salary_mean),float(Beijing_other_salary_mean)], 
  "marker": {"color": "rgb(255, 255, 204)"}, 
  "name": "Beijing", 
  "type": "bar", 
  "uid": "fe7f98", 
  "xsrc": "XinyuM:3:cee1e4", 
  "ysrc": "XinyuM:3:58dd98"
}
trace2 = {
  "x": ["content generation", "marketing", "other related"], 
  "y": [float(shanghai_contend_salary_mean),float(shanghai_marketing_salary_mean),float(shanghai_other_salary_mean)], 
  "marker": {"color": "rgb(161, 218, 180)"}, 
  "name": "shanghai", 
  "type": "bar", 
  "uid": "a03931", 
  "xsrc": "XinyuM:3:cee1e4", 
  "ysrc": "XinyuM:3:23f69a"
}
trace3 = {
  "x": ["content generation", "marketing", "other related"], 
  "y": [float(guangzhou_contend_salary_mean),float(guangzhou_marketing_salary_mean),float(guangzhou_other_salary_mean)], 
  "marker": {"color": "rgb(65, 182, 196)"}, 
  "name": "Guangzhou", 
  "type": "bar", 
  "uid": "2ff10b", 
  "xsrc": "XinyuM:3:cee1e4", 
  "ysrc": "XinyuM:3:fc6adf"
}
trace4 = {
  "x": ["content generation", "marketing", "other related"], 
  "y": [float(contend_salary_mean), float(marketing_salary_mean),float(other_salary_mean)], 
  "marker": {"color": "rgb(44, 127, 184)"}, 
  "name": "shenzhen", 
  "type": "bar", 
  "uid": "f25fae", 
  "xsrc": "XinyuM:3:cee1e4", 
  "ysrc": "XinyuM:3:ee8231"
}
trace5 = {
  "x": ["content generation", "marketing", "other related"], 
  "y": [float(Hangzhou_contend_salary_mean),float(Hangzhou_marketing_salary_mean),float(Hangzhou_other_salary_mean)], 
  "marker": {"color": "rgb(8, 104, 172)"}, 
  "name": "Hangzhou", 
  "type": "bar", 
  "uid": "e55ccc", 
  "xsrc": "XinyuM:3:cee1e4", 
  "ysrc": "XinyuM:3:6a7458"
}
trace6 = {
  "x": ["content generation", "marketing", "other related"], 
  "y": [float(Chengdu_contend_salary_mean),float(Chengdu_marketing_salary_mean),float(Chengdu_other_salary_mean)], 
  "marker": {"color": "rgb(37, 52, 148)"}, 
  "name": "Chengdu", 
  "type": "bar", 
  "uid": "27f905", 
  "xsrc": "XinyuM:3:cee1e4", 
  "ysrc": "XinyuM:3:3b7d85"
}
data =[trace1, trace2, trace3, trace4, trace5, trace6]
layout = {
  "annotations": [
    {
      "x": 0.0762331838565, 
      "y": 5439.80314391, 
      "arrowsize": 1, 
      "ax": 0, 
      "ay": -32, 
      "font": {
        "color": "rgb(128, 0, 128)", 
        "size": 15
      }, 
      "showarrow": True, 
      "text": "<b>Shenzhen:5388.49RMB</b>", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 0.80269058296, 
      "y": 5876.40339625, 
      "ax": 0, 
      "ay": -52, 
      "font": {
        "color": "rgb(128, 0, 128)", 
        "size": 15
      }, 
      "showarrow": True, 
      "text": "<b>Shanghai:5832.25RMB</b>", 
      "xref": "x", 
      "yref": "y"
    }, 
    {
      "x": 2.07623318386, 
      "y": 5677.79731725, 
      "ax": 0, 
      "ay": -42, 
      "font": {
        "color": "rgb(128, 0, 128)", 
        "size": 15
      }, 
      "showarrow": True, 
      "text": "<b>Shenzhen:5647.52RMB</b>", 
      "xref": "x", 
      "yref": "y"
    }
  ], 
  "barmode": "group", 
  "title": "Average Salary in 6 Cities", 
  "xaxis": {
    "autorange": True, 
    "range": [-0.5, 2.5], 
    "tickangle": -25, 
    "title": "Position", 
    "type": "category"
  }, 
  "yaxis": {
    "autorange": True, 
    "range": [0, 7383.47305453], 
    "title": "Salary", 
    "type": "linear"
  }
}
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='angled-text-bar')
# Out:
# <div id="c0e87654-c7af-4252-9bec-06716cbd2395" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c0e87654-c7af-4252-9bec-06716cbd2395", [{"type": "bar", "x": ["content generation", "marketing", "other related"], "y": [4868.145363408522, 5409.633649932158, 5485.056497175141], "marker": {"color": "rgb(255, 255, 204)"}, "name": "Beijing", "uid": "fe7f98", "xsrc": "XinyuM:3:cee1e4", "ysrc": "XinyuM:3:58dd98"}, {"type": "bar", "x": ["content generation", "marketing", "other related"], "y": [5250.900243309002, 5832.246085011187, 5525.451197053408], "marker": {"color": "rgb(161, 218, 180)"}, "name": "shanghai", "uid": "a03931", "xsrc": "XinyuM:3:cee1e4", "ysrc": "XinyuM:3:23f69a"}, {"type": "bar", "x": ["content generation", "marketing", "other related"], "y": [4850.314465408805, 5099.300628930818, 5075.971370143149], "marker": {"color": "rgb(65, 182, 196)"}, "name": "Guangzhou", "uid": "2ff10b", "xsrc": "XinyuM:3:cee1e4", "ysrc": "XinyuM:3:fc6adf"}, {"type": "bar", "x": ["content generation", "marketing", "other related"], "y": [5388.489208633094, 5305.8451816745655, 5647.527910685805], "marker": {"color": "rgb(44, 127, 184)"}, "name": "shenzhen", "uid": "f25fae", "xsrc": "XinyuM:3:cee1e4", "ysrc": "XinyuM:3:ee8231"}, {"type": "bar", "x": ["content generation", "marketing", "other related"], "y": [4955.072463768116, 5514.323748668797, 4845.168539325843], "marker": {"color": "rgb(8, 104, 172)"}, "name": "Hangzhou", "uid": "e55ccc", "xsrc": "XinyuM:3:cee1e4", "ysrc": "XinyuM:3:6a7458"}, {"type": "bar", "x": ["content generation", "marketing", "other related"], "y": [3893.150684931507, 4287.455197132616, 4110.46511627907], "marker": {"color": "rgb(37, 52, 148)"}, "name": "Chengdu", "uid": "27f905", "xsrc": "XinyuM:3:cee1e4", "ysrc": "XinyuM:3:3b7d85"}], {"annotations": [{"x": 0.0762331838565, "y": 5439.80314391, "arrowsize": 1, "ax": 0, "ay": -32, "font": {"color": "rgb(128, 0, 128)", "size": 15}, "showarrow": true, "text": "<b>Shenzhen:5388.49RMB</b>", "xref": "x", "yref": "y"}, {"x": 0.80269058296, "y": 5876.40339625, "ax": 0, "ay": -52, "font": {"color": "rgb(128, 0, 128)", "size": 15}, "showarrow": true, "text": "<b>Shanghai:5832.25RMB</b>", "xref": "x", "yref": "y"}, {"x": 2.07623318386, "y": 5677.79731725, "ax": 0, "ay": -42, "font": {"color": "rgb(128, 0, 128)", "size": 15}, "showarrow": true, "text": "<b>Shenzhen:5647.52RMB</b>", "xref": "x", "yref": "y"}], "barmode": "group", "title": "Average Salary in 6 Cities", "xaxis": {"autorange": true, "range": [-0.5, 2.5], "tickangle": -25, "title": "Position", "type": "category"}, "yaxis": {"autorange": true, "range": [0, 7383.47305453], "title": "Salary", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
trace1 = go.Bar(
    y=['other related', 'marketing', 'content<br>generation'],
    x=[Beijing_other_position, Beijing_marketing_position, Beijing_content_position],
    name='Beijing',
    orientation = 'h',
    marker = dict(
        color = 'rgb(255, 255, 204)',
        line = dict(
            color = 'rgb(255, 255, 204)',
            width = 3)
    )
)
trace2 = go.Bar(
    y=['other related', 'marketing', 'content<br>generation'],
    x=[shanghai_other_position, shanghai_marketing_position, shanghai_content_position],
    name='Shanghai',
    orientation = 'h',
    marker = dict(
        color = 'rgb(161, 218, 180)',
        line = dict(
            color = 'rgb(161, 218, 180)',
            width = 3)
    )
)
trace3 = go.Bar(
    y=['other related', 'marketing', 'content<br>generation'],
    x=[guangzhou_other_position, guangzhou_marketing_position, guangzhou_content_position],
    name='Guangzhou',
    orientation = 'h',
    marker = dict(
        color = 'rgb(65, 182, 196)',
        line = dict(
            color = 'rgb(65, 182, 196)',
            width = 3)
    )
)
trace4 = go.Bar(
    y=['other related', 'marketing', 'content<br>generation'],
    x=[other_position, marketing_position, content_position],
    name='Shenzhen',
    orientation = 'h',
    marker = dict(
        color = 'rgb(44, 127, 184)',
        line = dict(
            color = 'rgb(44, 127, 184)',
            width = 3)
    )
)
trace5 = go.Bar(
    y=['other related', 'marketing', 'content<br>generation'],
    x=[Hangzhou_other_position, Hangzhou_marketing_position, Hangzhou_content_position],
    name='Hangzhou',
    orientation = 'h',
    marker = dict(
        color = 'rgb(8, 104, 172)',
        line = dict(
            color = 'rgb(8, 104, 172)',
            width = 3)
    )
)
trace6 = go.Bar(
    y=['other related', 'marketing', 'content<br>generation'],
    x=[Chengdu_other_position, Chengdu_marketing_position, chengdu_content_position],
    name='Chengdu',
    orientation = 'h',
    marker = dict(
        color = 'rgb(37, 52, 148)',
        line = dict(
            color = 'rgb(37, 52, 148)',
            width = 3)
    )
)



data = [trace1, trace2,trace3,trace4,trace5,trace6]
layout = {
  "barmode": "stack", 
  "title": "Communication&Media Related Jobs", 
  "xaxis": {
    "autorange": True, 
    "range": [0, 4573.68421053], 
    "title": "Click to enter X axis title", 
    "type": "linear"
  }, 
  "yaxis": {
    "autorange": True, 
    "range": [-0.5, 2.5], 
    "type": "category"
  }
}

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='marker-h-bar')
# Out:
# <div id="9f688132-1b9a-47d1-b093-e4bf86e7ae48" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9f688132-1b9a-47d1-b093-e4bf86e7ae48", [{"type": "bar", "y": ["other related", "marketing", "content<br>generation"], "x": [354, 737, 266], "name": "Beijing", "orientation": "h", "marker": {"color": "rgb(255, 255, 204)", "line": {"color": "rgb(255, 255, 204)", "width": 3}}}, {"type": "bar", "y": ["other related", "marketing", "content<br>generation"], "x": [181, 745, 137], "name": "Shanghai", "orientation": "h", "marker": {"color": "rgb(161, 218, 180)", "line": {"color": "rgb(161, 218, 180)", "width": 3}}}, {"type": "bar", "y": ["other related", "marketing", "content<br>generation"], "x": [326, 1325, 318], "name": "Guangzhou", "orientation": "h", "marker": {"color": "rgb(65, 182, 196)", "line": {"color": "rgb(65, 182, 196)", "width": 3}}}, {"type": "bar", "y": ["other related", "marketing", "content<br>generation"], "x": [209, 633, 139], "name": "Shenzhen", "orientation": "h", "marker": {"color": "rgb(44, 127, 184)", "line": {"color": "rgb(44, 127, 184)", "width": 3}}}, {"type": "bar", "y": ["other related", "marketing", "content<br>generation"], "x": [89, 626, 69], "name": "Hangzhou", "orientation": "h", "marker": {"color": "rgb(8, 104, 172)", "line": {"color": "rgb(8, 104, 172)", "width": 3}}}, {"type": "bar", "y": ["other related", "marketing", "content<br>generation"], "x": [86, 279, 73], "name": "Chengdu", "orientation": "h", "marker": {"color": "rgb(37, 52, 148)", "line": {"color": "rgb(37, 52, 148)", "width": 3}}}], {"barmode": "stack", "title": "Communication&Media Related Jobs", "xaxis": {"autorange": true, "range": [0, 4573.68421053], "title": "Click to enter X axis title", "type": "linear"}, "yaxis": {"autorange": true, "range": [-0.5, 2.5], "type": "category"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
df= pd.read_excel('6城市近5年商品房销售平均价格.xlsx')

# %%
trace1 = go.Scatter(
    x=df.index,
    y=df['北京'].values,
    name = 'Beijing',
    marker=dict(
        color='rgb(255, 255, 204)',
    )
)
trace2 = go.Scatter(
    x=df.index,
    y=df['上海'].values,
    name = 'Shanghai',
    marker=dict(
        color='rgb(161, 218, 180)',
    )
)
trace3 = go.Scatter(
    x=df.index,
    y=df['广州'].values,
    name = 'Guangzhou',
    marker=dict(
        color='rgb(65, 182, 196)',
    )
)
trace4 = go.Scatter(
    x=df.index,
    y=df['深圳'].values,
    name = 'Shenzhen',
    marker=dict(
        color='rgb(44, 127, 184)',
    )
)
trace5 = go.Scatter(
    x=df.index,
    y=df['杭州'].values,
    name = 'Hangzhou',
    marker=dict(
        color='rgb(8, 104, 172)',
    )
)
trace6 = go.Scatter(
    x=df.index,
    y=df['成都'].values,
    name = 'Chengdu',
    marker=dict(
        color='rgb(37, 52, 148)',
    )
)

data = [trace1, trace2,trace3,trace4,trace5,trace6]
iplot({"data":data, 
       "layout": Layout(title="Average Commercial Housing Price from 2012-2017")
      })
# Out:
# <div id="524ffbac-54af-41a8-b21a-052fa8fa0e32" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("524ffbac-54af-41a8-b21a-052fa8fa0e32", [{"type": "scatter", "x": [2012, 2013, 2014, 2015, 2016, 2017], "y": [30138, 40342, 37294, 39437, 57597, 57768], "name": "Beijing", "marker": {"color": "rgb(255, 255, 204)"}}, {"type": "scatter", "x": [2012, 2013, 2014, 2015, 2016, 2017], "y": [23428, 29978, 30522, 35237, 52142, 50017], "name": "Shanghai", "marker": {"color": "rgb(161, 218, 180)"}}, {"type": "scatter", "x": [2012, 2013, 2014, 2015, 2016, 2017], "y": [16555, 19208, 18564, 20016, 22926, 27578], "name": "Guangzhou", "marker": {"color": "rgb(65, 182, 196)"}}, {"type": "scatter", "x": [2012, 2013, 2014, 2015, 2016, 2017], "y": [19298, 24910, 28117, 41494, 44060, 47996], "name": "Shenzhen", "marker": {"color": "rgb(44, 127, 184)"}}, {"type": "scatter", "x": [2012, 2013, 2014, 2015, 2016, 2017], "y": [18713, 19131, 16984, 16080, 19553, 21929], "name": "Hangzhou", "marker": {"color": "rgb(8, 104, 172)"}}, {"type": "scatter", "x": [2012, 2013, 2014, 2015, 2016, 2017], "y": [8450, 8597, 8277, 8213, 8591, 12034], "name": "Chengdu", "marker": {"color": "rgb(37, 52, 148)"}}], {"title": "Average Commercial Housing Price from 2012-2017"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
Beijing_per_year=(Beijing_contend_salary_mean+Beijing_marketing_salary_mean+Beijing_other_salary_mean)/3*12
Beijing_rate=54559*80/Beijing_per_year
Shanghai_per_year=(shanghai_contend_salary_mean+shanghai_marketing_salary_mean+shanghai_contend_salary_mean)/3*12
Shanghai_rate=50527*80/Shanghai_per_year
Guangzhou_per_year=(guangzhou_contend_salary_mean+guangzhou_marketing_salary_mean+guangzhou_other_salary_mean)/3*12
Guangzhou_rate=28586*80/Guangzhou_per_year
Shenzhen_per_year=(contend_salary_mean+marketing_salary_mean+other_salary_mean)/3*12
Shenzhen_rate=48997*80/Shenzhen_per_year
Hangzhou_per_year=(Hangzhou_contend_salary_mean+Hangzhou_marketing_salary_mean+Hangzhou_other_salary_mean)/3*12
Hangzhou_rate=20930*80/Hangzhou_per_year
Chengdu_per_year=(Chengdu_contend_salary_mean+Chengdu_marketing_salary_mean+Chengdu_other_salary_mean)/3*12
Chengdu_rate=13023*80/Chengdu_per_year

# %%
Chengdu_rate
# Out:
# Salary_per_month    21.190993
# dtype: float64

# %%
from plotly import tools

import numpy as np

y_saving = [float(Chengdu_rate),float(Hangzhou_rate),float(Guangzhou_rate),float(Shenzhen_rate),
            float(Shanghai_rate), float(Beijing_rate)]
y_net_worth = [13023, 20930,28586,48997,50527, 54559]
x_saving = ['Chengdu', 'Hangzhou', 'Guangzhou', 'Shengzhen',
            'Shanghai', 'Beijing']
x_net_worth = ['Chengdu', 'Hangzhou','Guangzhou','Shengzhen',
            'Shanghai', 'Beijing']
trace0 = go.Bar(
    x=y_saving,
    y=x_saving,
    marker=dict(
        color='rgb(37, 52, 148)',
        line=dict(
            color='rgb(37, 52, 148)',
            width=1),
    ),
    name='HousingPrice-to-Income Ratio',
    orientation='h',
)
trace1 = go.Scatter(
    x=y_net_worth,
    y=x_net_worth,
    mode='lines+markers',
    line=dict(
        color='rgb(128, 0, 128)'),
    name='Average commercial housing price on Apri 2018',
)
layout = dict(
    title='HousingPrice-to-Income Ratio & Average Housing Price',
    yaxis1=dict(
        showgrid=False,
        showline=False,
        showticklabels=True,
        domain=[0, 0.85],
    ),
    yaxis2=dict(
        showgrid=False,
        showline=True,
        showticklabels=False,
        linecolor='rgba(102, 102, 102, 0.8)',
        linewidth=2,
        domain=[0, 0.85],
    ),
    xaxis1=dict(
        zeroline=False,
        showline=False,
        showticklabels=True,
        showgrid=True,
        domain=[0, 0.42],
    ),
    xaxis2=dict(
        zeroline=False,
        showline=False,
        showticklabels=True,
        showgrid=True,
        domain=[0.47, 1],
        side='top',
        dtick=25000,
    ),
    legend=dict(
        x=0.029,
        y=1.038,
        font=dict(
            size=10,
        ),
    ),
    margin=dict(
        l=100,
        r=20,
        t=70,
        b=70,
    ),
    paper_bgcolor='rgb(253, 253, 253)',
    plot_bgcolor='rgba(252, 252, 252, 0.06)',
)

annotations = []

y_s = np.round(y_saving, decimals=2)
y_nw = np.rint(y_net_worth)

# Adding labels
for ydn, yd, xd in zip(y_nw, y_s, x_saving):
    # labeling the scatter savings
    annotations.append(dict(xref='x2', yref='y2',
                            y=xd, x=ydn - 20000,
                            text='{:,}'.format(ydn) + 'RMB',
                            font=dict(family='Arial', size=12,
                                      color='rgb(128, 0, 128)'),
                            showarrow=False))
    # labeling the bar net worth
    annotations.append(dict(xref='x1', yref='y1',
                            y=xd, x=yd + 5,
                            text=str(yd),
                            font=dict(family='Arial', size=12,
                                      color='rgb(37, 52, 148)'),
                            showarrow=False))

layout['annotations'] = annotations

# Creating two subplots
fig = tools.make_subplots(rows=1, cols=2, specs=[[{}, {}]], shared_xaxes=True,
                          shared_yaxes=False, vertical_spacing=0.001)

fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)

fig['layout'].update(layout)
iplot(fig, filename='oecd-networth-saving-bar-line')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# <div id="bb280bda-ec06-464a-b846-59bd144dd3fb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bb280bda-ec06-464a-b846-59bd144dd3fb", [{"type": "bar", "x": [21.190993041624235, 27.33345718831596, 38.04976273980534, 59.96501389810554, 61.86709432769829, 69.22485483478171], "y": ["Chengdu", "Hangzhou", "Guangzhou", "Shengzhen", "Shanghai", "Beijing"], "marker": {"color": "rgb(37, 52, 148)", "line": {"color": "rgb(37, 52, 148)", "width": 1}}, "name": "HousingPrice-to-Income Ratio", "orientation": "h", "xaxis": "x1", "yaxis": "y1"}, {"type": "scatter", "x": [13023, 20930, 28586, 48997, 50527, 54559], "y": ["Chengdu", "Hangzhou", "Guangzhou", "Shengzhen", "Shanghai", "Beijing"], "mode": "lines+markers", "line": {"color": "rgb(128, 0, 128)"}, "name": "Average commercial housing price on Apri 2018", "xaxis": "x2", "yaxis": "y2"}], {"xaxis1": {"domain": [0, 0.42], "anchor": "y1", "zeroline": false, "showline": false, "showticklabels": true, "showgrid": true}, "yaxis1": {"domain": [0, 0.85], "anchor": "x1", "showgrid": false, "showline": false, "showticklabels": true}, "xaxis2": {"domain": [0.47, 1], "anchor": "y2", "zeroline": false, "showline": false, "showticklabels": true, "showgrid": true, "side": "top", "dtick": 25000}, "yaxis2": {"domain": [0, 0.85], "anchor": "x2", "showgrid": false, "showline": true, "showticklabels": false, "linecolor": "rgba(102, 102, 102, 0.8)", "linewidth": 2}, "title": "HousingPrice-to-Income Ratio & Average Housing Price", "legend": {"x": 0.029, "y": 1.038, "font": {"size": 10}}, "margin": {"l": 100, "r": 20, "t": 70, "b": 70}, "paper_bgcolor": "rgb(253, 253, 253)", "plot_bgcolor": "rgba(252, 252, 252, 0.06)", "annotations": [{"xref": "x2", "yref": "y2", "y": "Chengdu", "x": -6977.0, "text": "13,023.0RMB", "font": {"family": "Arial", "size": 12, "color": "rgb(128, 0, 128)"}, "showarrow": false}, {"xref": "x1", "yref": "y1", "y": "Chengdu", "x": 26.19, "text": "21.19", "font": {"family": "Arial", "size": 12, "color": "rgb(37, 52, 148)"}, "showarrow": false}, {"xref": "x2", "yref": "y2", "y": "Hangzhou", "x": 930.0, "text": "20,930.0RMB", "font": {"family": "Arial", "size": 12, "color": "rgb(128, 0, 128)"}, "showarrow": false}, {"xref": "x1", "yref": "y1", "y": "Hangzhou", "x": 32.33, "text": "27.33", "font": {"family": "Arial", "size": 12, "color": "rgb(37, 52, 148)"}, "showarrow": false}, {"xref": "x2", "yref": "y2", "y": "Guangzhou", "x": 8586.0, "text": "28,586.0RMB", "font": {"family": "Arial", "size": 12, "color": "rgb(128, 0, 128)"}, "showarrow": false}, {"xref": "x1", "yref": "y1", "y": "Guangzhou", "x": 43.05, "text": "38.05", "font": {"family": "Arial", "size": 12, "color": "rgb(37, 52, 148)"}, "showarrow": false}, {"xref": "x2", "yref": "y2", "y": "Shengzhen", "x": 28997.0, "text": "48,997.0RMB", "font": {"family": "Arial", "size": 12, "color": "rgb(128, 0, 128)"}, "showarrow": false}, {"xref": "x1", "yref": "y1", "y": "Shengzhen", "x": 64.97, "text": "59.97", "font": {"family": "Arial", "size": 12, "color": "rgb(37, 52, 148)"}, "showarrow": false}, {"xref": "x2", "yref": "y2", "y": "Shanghai", "x": 30527.0, "text": "50,527.0RMB", "font": {"family": "Arial", "size": 12, "color": "rgb(128, 0, 128)"}, "showarrow": false}, {"xref": "x1", "yref": "y1", "y": "Shanghai", "x": 66.87, "text": "61.87", "font": {"family": "Arial", "size": 12, "color": "rgb(37, 52, 148)"}, "showarrow": false}, {"xref": "x2", "yref": "y2", "y": "Beijing", "x": 34559.0, "text": "54,559.0RMB", "font": {"family": "Arial", "size": 12, "color": "rgb(128, 0, 128)"}, "showarrow": false}, {"xref": "x1", "yref": "y1", "y": "Beijing", "x": 74.22, "text": "69.22", "font": {"family": "Arial", "size": 12, "color": "rgb(37, 52, 148)"}, "showarrow": false}]}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
